# %% [markdown]
# <a href="https://colab.research.google.com/github/edik06031-rgb/DTA_2026/blob/main/classmade/Intro_to_modus.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Знайомство з модулями у python

# %%
import random  # random.randrange()
from random import randrange  # randrange()

from random import *  #  randrange()
import random as rnd  # rnd.randrange()
from random import randrange as rndrng  # rndrng()

# %%
list(range(1, 11, 2))
# Out:
# [1, 3, 5, 7, 9]

# %%
import random  # random.randrange()

# %%
random.randrange(1, 11, 2)
# Out:
# 5

# %%
random.choice(["q", "w"])
# Out:
# 'q'

# %%
def function():
  d = list(range(1, 11, 2))
  print(d)
  d[-1] += 1
  print(d)

function()
# Out:
# [1, 3, 5, 7, 9]
# [1, 3, 5, 7, 10]
